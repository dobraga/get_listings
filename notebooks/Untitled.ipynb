# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
from datetime import datetime
import folium

pd.set_option('display.max_columns', None)

# %%
engine = create_engine("postgresql://postgres:postgres@localhost:15432/listing")

# %%
df = pd.read_sql("SELECT url, raw FROM imovel", engine)
df = pd.concat([df, pd.json_normalize(df.raw)], axis=1)
df.sample(3)
# Out:
#                                                      url  \
# 3331   https://www.vivareal.com.br/imovel/casa-6-quar...
# 2484   https://www.zapimoveis.com.br/imovel/aluguel-a...
# 20809  https://www.zapimoveis.com.br/imovel/aluguel-a...
#
#                                                      raw  \
# 3331   {'listing': {'displayAddressType': 'NEIGHBORHO...
# 2484   {'listing': {'displayAddressType': 'NEIGHBORHO...
# 20809  {'listing': {'displayAddressType': 'STREET', '...
#
#                                                   medias  \
# 3331   [{'url': 'https://resizedimgs.vivareal.com/{ac...
# 2484   [{'url': 'https://resizedimgs.zapimoveis.com.b...
# 20809  [{'url': 'https://resizedimgs.zapimoveis.com.b...
#
#       listing.displayAddressType  \
# 3331                NEIGHBORHOOD
# 2484                NEIGHBORHOOD
# 20809                     STREET
#
#                                        listing.amenities listing.usableAreas  \
# ...

# %%
pd.json_normalize(df["listing.pricingInfos"].explode()).query("`businessType` != 'SALE' and `rentalInfo.period` != 'MONTHLY'")
# Out:
#       price businessType monthlyCondoFee rentalInfo.period  \
# 321     310       RENTAL               0             DAILY
# 617    5000       RENTAL               0             DAILY
# 658    3000       RENTAL            1850             DAILY
# 1024     80       RENTAL             NaN             DAILY
# 1442   3000       RENTAL            2500             DAILY
# ...     ...          ...             ...               ...
# 29733  5500       RENTAL             NaN             DAILY
# 29754  2400       RENTAL             NaN             DAILY
# 29900   250       RENTAL             NaN             DAILY
# 29903   180       RENTAL             NaN             DAILY
# 30000  4000       RENTAL            2300             DAILY
#
#                                    rentalInfo.warranties  \
# 321                                                   []
# 617                                                   []
# 658                                                   []
# ...

# %%
df.iloc[617,:]#.values
# Out:
# url                                https://www.vivareal.com.br/imovel/apartamento...
# raw                                {'listing': {'displayAddressType': 'STREET', '...
# medias                             [{'url': 'https://resizedimgs.vivareal.com/{ac...
# listing.displayAddressType                                                    STREET
# listing.amenities                  [POOL, FURNISHED, KITCHEN_CABINETS, AIR_CONDIT...
#                                                          ...
# account.minisite.logoUrl                                                         NaN
# account.minisite.coverUrl                                                        NaN
# account.minisite.coverUrlMobile                                                  NaN
# account.minisite.description                                                     NaN
# listing.advertiserContact.chat                                                   NaN
# Name: 617, Length: 92, dtype: object
